# %% [markdown]
# ## Course1 : Foundation of information

# %% [markdown]
# **Assignment**: Data extraction and analysis from social media platform Youtube ( 30 Marks )

# %% [markdown]
# **Problem statement**
#
# Videos are a fast growing medium where people communicate, share knowledge, showcase skills etc. YouTube is one of the biggest platforms which hosts videos. The YouTube platform hosts content from many different professions/arts/ cultures across the world.
#
# People can express their opinion about the video in the form of likes, dislikes, comments which are features provided by the YouTube platform which provides the information on the sentiment about the video.
#
# The assignment involves the steps on programmatic data extraction from YouTube on which analysis can be conducted to understand various attributes related to a video.

# %% [markdown]
# **Steps to be performed**

# %% [markdown]
# 1. Connect to the Youtube API using a Python client ( 5 Marks )

# %% [markdown]
# > 1.a Create a YouTube API key (3 marks)

# %%
pip install python-dotenv
# Out:
# Collecting python-dotenv
#   Obtaining dependency information for python-dotenv from https://files.pythonhosted.org/packages/6a/3e/b68c118422ec867fa7ab88444e1274aa40681c606d59ac27de5a5588f082/python_dotenv-1.0.1-py3-none-any.whl.metadata
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.1
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# donot save api key here - security reasons - pick from .env files
import os
from dotenv import load_dotenv

# Load the environment variables from .env file
load_dotenv()

api_service_name = "youtube"
api_version = "v3"
developer_key = os.getenv("GCLOUD_API_KEY")

# %% [markdown]
# > 1.b Install the Google API python client  (2 marks)

# %%
pip install google-api-python-client
# Out:
# Collecting google-api-python-client
#   Obtaining dependency information for google-api-python-client from https://files.pythonhosted.org/packages/73/e4/d8d38ca79045a72880c98e6d2ebc737c92d596d5dc0bf2e4233b00be5daa/google_api_python_client-2.116.0-py2.py3-none-any.whl.metadata
#   Downloading google_api_python_client-2.116.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting httplib2<1.dev0,>=0.15.0 (from google-api-python-client)
#   Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.9/96.9 kB 2.5 MB/s eta 0:00:00a 0:00:01
# Collecting google-auth<3.0.0.dev0,>=1.19.0 (from google-api-python-client)
#   Obtaining dependency information for google-auth<3.0.0.dev0,>=1.19.0 from https://files.pythonhosted.org/packages/82/41/7fb855444cead5b2213e053447ce3a0b7bf2c3529c443e0cf75b2f13b405/google_auth-2.27.0-py2.py3-none-any.whl.metadata
#   Downloading google_auth-2.27.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-httplib2>=0.1.0 (from google-api-python-client)
#   Obtaining dependency information for google-auth-httplib2>=0.1.0 from https://files.pythonhosted.org/packages/be/8a/fe34d2f3f9470a27b01c9e76226965863f153d5fbe276f83608562e49c04/google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata
#   Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 (from google-api-python-client)
#   Obtaining dependency information for google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 from https://files.pythonhosted.org/packages/29/37/f7d78e23eb97c1c1753163d5c0734ae8a412d829dbe6e1527f486664f483/google_api_core-2.16.2-py3-none-any.whl.metadata
#   Downloading google_api_core-2.16.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client)
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client)
#   Obtaining dependency information for googleapis-common-protos<2.0.dev0,>=1.56.2 from https://files.pythonhosted.org/packages/f0/43/c9d8f75ddf08e2a0a27db243c13a700c3cc7ec615b545b697cf6f715ad92/googleapis_common_protos-1.62.0-py2.py3-none-any.whl.metadata
#   Downloading googleapis_common_protos-1.62.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /opt/homebrew/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (4.25.0)
# Collecting requests<3.0.0.dev0,>=2.18.0 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client)
#   Obtaining dependency information for requests<3.0.0.dev0,>=2.18.0 from https://files.pythonhosted.org/packages/70/8e/0e2d847013cb52cd35b38c009bb167a1a26b2ce6cd6965bf26b47bc0bf44/requests-2.31.0-py3-none-any.whl.metadata
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client)
#   Obtaining dependency information for cachetools<6.0,>=2.0.0 from https://files.pythonhosted.org/packages/a2/91/2d843adb9fbd911e0da45fbf6f18ca89d07a087c3daa23e955584f90ebf4/cachetools-5.3.2-py3-none-any.whl.metadata
#   Downloading cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client)
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 5.3 MB/s eta 0:00:00
# Collecting rsa<5,>=3.1.4 (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client)
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 (from httplib2<1.dev0,>=0.15.0->google-api-python-client)
#   Obtaining dependency information for pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 from https://files.pythonhosted.org/packages/39/92/8486ede85fcc088f1b3dba4ce92dd29d126fd96b0008ea213167940a2475/pyparsing-3.1.1-py3-none-any.whl.metadata
#   Downloading pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client)
#   Obtaining dependency information for pyasn1<0.6.0,>=0.4.6 from https://files.pythonhosted.org/packages/d1/75/4686d2872bf2fc0b37917cbc8bbf0dd3a5cdb0990799be1b9cbf1e1eb733/pyasn1-0.5.1-py2.py3-none-any.whl.metadata
#   Downloading pyasn1-0.5.1-py2.py3-none-any.whl.metadata (8.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client)
#   Obtaining dependency information for charset-normalizer<4,>=2 from https://files.pythonhosted.org/packages/dd/51/68b61b90b24ca35495956b718f35a9756ef7d3dd4b3c1508056fa98d1a1b/charset_normalizer-3.3.2-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading charset_normalizer-3.3.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client)
#   Obtaining dependency information for idna<4,>=2.5 from https://files.pythonhosted.org/packages/c2/e7/a82b05cf63a603df6e68d59ae6a68bf5064484a0718ea5033660af4b54a9/idna-3.6-py3-none-any.whl.metadata
#   Downloading idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client)
#   Obtaining dependency information for urllib3<3,>=1.21.1 from https://files.pythonhosted.org/packages/88/75/311454fd3317aefe18415f04568edc20218453b709c63c58b9292c71be17/urllib3-2.2.0-py3-none-any.whl.metadata
#   Downloading urllib3-2.2.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client)
#   Obtaining dependency information for certifi>=2017.4.17 from https://files.pythonhosted.org/packages/ba/06/a07f096c664aeb9f01624f858c3add0a4e913d6c96257acb4fce61e7de14/certifi-2024.2.2-py3-none-any.whl.metadata
#   Downloading certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Downloading google_api_python_client-2.116.0-py2.py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 14.1 MB/s eta 0:00:0000:0100:01
# Downloading google_api_core-2.16.2-py3-none-any.whl (135 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.2/135.2 kB 9.6 MB/s eta 0:00:00
# Downloading google_auth-2.27.0-py2.py3-none-any.whl (186 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 186.8/186.8 kB 9.1 MB/s eta 0:00:00
# Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Downloading cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Downloading googleapis_common_protos-1.62.0-py2.py3-none-any.whl (228 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.7/228.7 kB 7.4 MB/s eta 0:00:00
# Downloading pyparsing-3.1.1-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.1/103.1 kB 8.8 MB/s eta 0:00:00
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 6.7 MB/s eta 0:00:00
# Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 11.7 MB/s eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp311-cp311-macosx_11_0_arm64.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.0/119.0 kB 9.7 MB/s eta 0:00:00
# Downloading idna-3.6-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 7.8 MB/s eta 0:00:00
# Downloading pyasn1-0.5.1-py2.py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 7.7 MB/s eta 0:00:00
# Downloading urllib3-2.2.0-py3-none-any.whl (120 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.9/120.9 kB 10.3 MB/s eta 0:00:00
# Installing collected packages: urllib3, uritemplate, pyparsing, pyasn1, idna, googleapis-common-protos, charset-normalizer, certifi, cachetools, rsa, requests, pyasn1-modules, httplib2, google-auth, google-auth-httplib2, google-api-core, google-api-python-client
# Successfully installed cachetools-5.3.2 certifi-2024.2.2 charset-normalizer-3.3.2 google-api-core-2.16.2 google-api-python-client-2.116.0 google-auth-2.27.0 google-auth-httplib2-0.2.0 googleapis-common-protos-1.62.0 httplib2-0.22.0 idna-3.6 pyasn1-0.5.1 pyasn1-modules-0.3.0 pyparsing-3.1.1 requests-2.31.0 rsa-4.9 uritemplate-4.1.1 urllib3-2.2.0
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# refer to the [supporting](https://developers.google.com/youtube/v3/getting-started) link on how to create YouTube API Key

# %% [markdown]
# Reference link : https://developers.google.com/youtube/v3/quickstart/python

# %%
import googleapiclient.discovery
from pprint import pprint

# Resource contruction: api_service_name, api_version, developer_key already loaded in previous code block
youtube = googleapiclient.discovery.build(api_service_name, api_version, developerKey=developer_key)

# %% [markdown]
# 2. Search and extract the data

# %% [markdown]
# > 2.a Search videos related to the query string  “avatar movie”
# (For this part, choose/search one video of your choice and perform data collection steps on that specific video ) (3 marks)
#
# > Output expected : ID, Snippet with following attributes Channel ID, Video Description, Channel Title, Video Title

# %% [markdown]
# Reference link:  https://developers.google.com/youtube/v3/docs/search/list

# %%
# How many results should we fetch? Is there a specific format in which we should print the results? What all does perform data collection step include?
request = youtube.search().list(
  part="id,snippet",
  type="video",
  q="avatar movie",
  maxResults=1,
  fields="items(id(videoId),snippet(channelId,description,channelTitle,title))"
)

def get_formatted_search_results(response):
  to_return = []
  for data in response.get('items', []):
    to_return.append({
      'id': data['id']['videoId'],
      'snippet': {
        'channel_id': data['snippet']['channelId'],
        'video_description': data['snippet']['description'],
        'channel_title': data['snippet']['channelTitle'],
        'video_title': data['snippet']['title'],
      }
    })
  return to_return

try:
  search_response = request.execute()
  avatar_movie_results = get_formatted_search_results(search_response)
  pprint(avatar_movie_results)
except googleapiclient.errors.HttpError as e:
  # Handle HTTP errors
  print("An HTTP error occurred:", e.resp.status, e.content)
except googleapiclient.errors.Error as e:
  # Handle other googleapiclient errors
  print("An error occurred:", e)
except Exception as e:
  # Handle other exceptions, such as connection errors
  print("An unexpected error occurred:", str(e))
# Out:
# [{'id': 'PLtgIILX7E8',
#   'snippet': {'channel_id': 'UC0A86RKLCqTEUna3hPlEpzg',
#               'channel_title': 'Superhero FXL Games',
#               'video_description': 'AVATAR Full Movie 2023: Fallen Kingdom | '
#                                    'Superhero FXL Action Movies 2023 in '
#                                    'English (Game Movie). Best Action Game ...',
#               'video_title': 'AVATAR Full Movie 2023: Fallen Kingdom | '
#                              'Superhero FXL Action Movies 2023 in English '
#                              '(Game Movie)'}}]

# %% [markdown]
# > 2.b  Provide the following statistics for query string “avatar movie” of top 50 videos sorted by relevance in the US region ( 7 marks )
#
# > Output expected: video ID, title, no of views, no of likes,no of comments exported to CSV file

# %% [markdown]
# Reference link: https://developers.google.com/youtube/v3/docs/videos/list

# %%
import csv 

# fetching 50 results, order/sort by relevance is default, regionCode = US
search_req = youtube.search().list(
  part="id,snippet",
  type="video",
  q="avatar movie",
  maxResults=50,
  regionCode="US",
  fields="items(id(videoId),snippet(title))"
)

# method to call video api to get statistics of the videos with ids fetched from previous request, use try catch if neccessary
def video_api_request(video_ids):
  request_2b_video = youtube.videos().list(
    part="id,statistics",
    id=",".join(video_ids),
  )
  video_resp = request_2b_video.execute()
  return video_resp

# execution steps, add try catch if necessary
search_res = search_req.execute()

# keeping a map to reduce time complexity
search_video_results = {}
for res_data in search_res.get('items', []):
  video_id = res_data['id']['videoId']
  search_video_results[video_id] = {
    'id': video_id,
    'title': res_data['snippet']['title']
  }

# make a tuple for video api call to join and use
video_ids = tuple(search_video_results.keys())

video_api_response = video_api_request(video_ids)
for video_data in video_api_response.get('items', []):
  curr_id = video_data['id']
  curr_search_video = search_video_results[curr_id]
  curr_search_video['total_likes'] = video_data['statistics'].get('likeCount') # add default value as 0 if necessary
  curr_search_video['total_views'] = video_data['statistics'].get('viewCount')
  curr_search_video['total_comments'] = video_data['statistics'].get('commentCount')

fields = ['id', 'title', 'total_likes', 'total_views', 'total_comments']

filename = "assignment_2b.csv"

with open(filename, 'w') as csvfile:
  writer = csv.DictWriter(csvfile, fieldnames=fields)
  writer.writeheader()
  writer.writerows(list(search_video_results.values()))

# %%
pip install pandas

# %% [markdown]
#  3. Analyze the exported data obtained in 2.b and carry out the following tasks (15 marks )

# %% [markdown]
# > 3.a Sort the data 2.b  by top 10 comments in descending order and consider the video IDs and Titles of top 10 videos which have highest comments. (3mark)

# %%
import pandas as pd
# filename = "assignment_2b.csv" already declared in previous block
df = pd.read_csv(filename)

top_10_comments = df.sort_values('total_comments', ascending=False)[:10]
print(top_10_comments[["id", "title"]]) # Should I only show id and title of top 10 comments?
# Out:
#              id                                              title
# 7   d9MyW72ELq0        Avatar: The Way of Water | Official Trailer
# 1   waJKJW_XU90  Avatar: The Last Airbender | Official Teaser |...
# 48  a8Gx8wiNbs8  Avatar: The Way of Water | Official Teaser Tra...
# 13  2r71I8lvTIA  The Last Airbender Film: How it Disrespected a...
# 0   ByAn8DF8Ykk  Avatar: The Last Airbender | Official Trailer ...
# 14  -egQ79OrYCs  THE LAST AIRBENDER (2010) | Hollywood.com Movi...
# 47  zj6p5kYnPPY  Film Theory: END the Avatar Cycle! (Avatar the...
# 4   5PSNL1qE6VY  Avatar | Official Trailer (HD) | 20th Century FOX
# 36  eJBPO76TGUQ             Avatar: The Way of Water Pitch Meeting
# 35  RGx8rYbRVR4  Why People Hate Avatar: A Lesson In Lazy Comme...

# %% [markdown]
# > 3.b Use a suitable method to retrieve comments of those top 10 videos from 3.a. For doing this, write a program to loop through each video id from 3.a and pass in the part parameter set to "snippet", to retrieve basic details about the comments. Execute this request and print the response using the pprint() method.
#  - Note: pprint() will print out the response from the API in a more human-readable format.
# - Reference link:  [link](https://developers.google.com/youtube/v3/docs )
#
#
# > **Output expected** : Use the python library “ pprint “ to print the output of the program with the following properties  etag, items, id , kind, snippet and snippet to have the text display field which represents the comment of videos.

# %%
def comment_threads_api(video_id):
  try:
    results = youtube.commentThreads().list(
      part="id,snippet",
      videoId=video_id,
      textFormat="plainText"
    ).execute()
    return results
  except:
    return {}

comments_on_videos = []
for index, t_10c_row in top_10_comments.iterrows():
  video_id = t_10c_row['id']
  comment_threads_response = comment_threads_api(video_id)
  comments_on_videos.append(comment_threads_response)
  pprint(comment_threads_response)
# Out:
# {'etag': 'fMesKevlp3BImRgczvsvbGWJhjI',
#  'items': [{'etag': 'bJ4KIdiRec-mERPPzFwJScY5SOg',
#             'id': 'UgznmmfiK8a9pOGNVf14AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': '_cyiXDYL4qeckubL1aKnlBaNeRQ',
#                                             'id': 'UgznmmfiK8a9pOGNVf14AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UC59GRUoJK0KiQ2B-gSPViWw'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/@ambitious3164',
#                                                         'authorDisplayName': '@ambitious3164',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/m6FafV5RCUUAjsqsQLEdB79ZpJ8YijyQjnBKDQJn9SToocnie63cvtJ5TEfqTgilN_BXerhokg=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                         'likeCount': 1,
#                                                         'publishedAt': '2024-02-01T03:49:55Z',
#                                                         'textDisplay': 'What a '
#                                                                        'movie. '
#                                                                        'I '
#                                                                        'never '
#                                                                        'experienced '
#                                                                        'like '
#                                                                        'this ❤',
#                                                         'textOriginal': 'What '
#                                                                         'a '
#                                                                         'movie. '
#                                                                         'I '
#                                                                         'never '
#                                                                         'experienced '
#                                                                         'like '
#                                                                         'this '
#                                                                         '❤',
#                                                         'updatedAt': '2024-02-01T03:49:55Z',
#                                                         'videoId': 'd9MyW72ELq0',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': 'd9MyW72ELq0'}},
#            {'etag': 'tlLyigd_pnuVtfKCM9AqKvji-Zw',
#             'id': 'UgyOplRc_r-MNxlOaZN4AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': '0Ytqp_yaniYFvv8otEY-WD2DlSw',
#                                             'id': 'UgyOplRc_r-MNxlOaZN4AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UCHEC3-rlQs4elJtityE38rQ'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/@XeniusChannel',
#                                                         'authorDisplayName': '@XeniusChannel',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/CspRehnSOUWdwzcd6npvHm4ypJEAYuGNPdxUfsts1VrbDjR5zTFwi_QB6vnFad2i6kegQZ3SGA=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                         'likeCount': 1,
#                                                         'publishedAt': '2024-01-31T00:35:40Z',
#                                                         'textDisplay': '2:00  '
#                                                                        'I NEED '
#                                                                        'YOU TO '
#                                                                        'BE '
#                                                                        'STRONG....!!!!!   '
#                                                                        '2:09 '
#                                                                        'STRONG '
#                                                                        'HEART.. '
#                                                                        '😱\n'
#                                                                        'His '
#                                                                        'wife:  '
#                                                                        '2:12 😐',
#                                                         'textOriginal': '2:00  '
#                                                                         'I '
#                                                                         'NEED '
#                                                                         'YOU '
#                                                                         'TO BE '
#                                                                         'STRONG....!!!!!   '
#                                                                         '2:09 '
#                                                                         'STRONG '
#                                                                         'HEART.. '
#                                                                         '😱\n'
#                                                                         'His '
#                                                                         'wife:  '
#                                                                         '2:12 '
#                                                                         '😐',
#                                                         'updatedAt': '2024-01-31T00:37:04Z',
#                                                         'videoId': 'd9MyW72ELq0',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': 'd9MyW72ELq0'}},
#            {'etag': 'JYkkmI8JRzIi-uYZsv7rDJZvroQ',
#             'id': 'UgxhDRYo5xgEQjtMszp4AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': 'GnfJ7FhSd6KmMyuciAIBj_47TkY',
#                                             'id': 'UgxhDRYo5xgEQjtMszp4AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UCZZRl-rH3MAvokvyr2T1OSQ'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/@pintukhura3349',
#                                                         'authorDisplayName': '@pintukhura3349',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZS8T8_3VlxUDGvrXcQOnAyD7zxj3HqfY4_MaOA8_Dd0z45FTqUP67l_zaIDs_Jx=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                         'likeCount': 3,
#                                                         'publishedAt': '2024-01-30T16:03:04Z',
#                                                         'textDisplay': '2024 '
#                                                                        'batch '
#                                                                        'attendance '
#                                                                        '🤚',
#                                                         'textOriginal': '2024 '
#                                                                         'batch '
#                                                                         'attendance '
#                                                                         '🤚',
#                                                         'updatedAt': '2024-01-30T16:03:04Z',
#                                                         'videoId': 'd9MyW72ELq0',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': 'd9MyW72ELq0'}},
#            {'etag': '6trmoDUGZQ_1QZSYHfK62KRv48c',
#             'id': 'Ugwi3U45-H1g3sWTuSp4AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': '__5BwuKyU4V_TX731_nmJBA0Zh4',
#                                             'id': 'Ugwi3U45-H1g3sWTuSp4AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UCUhxe5alacVevQwYGAzXSKQ'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/@user-ml8um8ux5m',
#                                                         'authorDisplayName': '@user-ml8um8ux5m',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZRTw9NNlis9SKgnsQ2QaBIc8Ru60fXHR_xginIMQNoUavtCwFQyC3ywudCvOEuh=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                         'likeCount': 2,
#                                                         'publishedAt': '2024-01-27T05:11:47Z',
#                                                         'textDisplay': 'the 3d '
#                                                                        'is '
#                                                                        'perfect',
#                                                         'textOriginal': 'the '
#                                                                         '3d is '
#                                                                         'perfect',
#                                                         'updatedAt': '2024-01-27T05:11:47Z',
#                                                         'videoId': 'd9MyW72ELq0',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': 'd9MyW72ELq0'}},
#            {'etag': 'hlBj6fHgHD8MidjTNfRumYsYeT4',
#             'id': 'UgxHHxyX_Bo5avwhSs94AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': 'ifbqViVgR1qgRcJ4rK1x-62BVZs',
#                                             'id': 'UgxHHxyX_Bo5avwhSs94AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UCwg33N9HaeAVS02ttE-IzEA'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/@cinorikese5890',
#                                                         'authorDisplayName': '@cinorikese5890',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/SmgYtirFXpiygo-qKPMtCF577DC_rNg6yeXCO8TVd_SDdbo6Stv28LSCYAym1Nf5nCfRFAMK=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                         'likeCount': 1,
#                                                         'publishedAt': '2024-01-26T21:14:33Z',
#                                                         'textDisplay': 'the '
#                                                                        'film '
#                                                                        'was '
#                                                                        'shit '
#                                                                        'compared '
#                                                                        'to the '
#                                                                        'first '
#                                                                        'one',
#                                                         'textOriginal': 'the '
#                                                                         'film '
#                                                                         'was '
#                                                                         'shit '
#                                                                         'compared '
#                                                                         'to '
#                                                                         'the '
#                                                                         'first '
#                                                                         'one',
#                                                         'updatedAt': '2024-01-26T21:14:33Z',
#                                                         'videoId': 'd9MyW72ELq0',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 1,
#                         'videoId': 'd9MyW72ELq0'}},
#            {'etag': 'QwHC8S2wXmC0YYgNtm-XxcJdrsw',
#             'id': 'UgxGitT6aGM3tgMi3vl4AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': 'Z-FCLuAazzNCdKuTPz2XdfCuGhc',
#                                             'id': 'UgxGitT6aGM3tgMi3vl4AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UCkEKdLWrZMS1kuKShKEHL7g'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/@afdashtech5322',
#                                                         'authorDisplayName': '@afdashtech5322',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/QjaoBIF1kxHXfhjta8hNPRZcq-z70teMXuW_OOYX7XugwlppIz1ZIXwoGkfrnfAty32UE_BUFNA=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                         'likeCount': 2,
#                                                         'publishedAt': '2024-01-25T06:50:34Z',
#                                                         'textDisplay': 'Very '
#                                                                        'good '
#                                                                        'movie❤',
#                                                         'textOriginal': 'Very '
#                                                                         'good '
#                                                                         'movie❤',
#                                                         'updatedAt': '2024-01-25T06:50:34Z',
#                                                         'videoId': 'd9MyW72ELq0',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': 'd9MyW72ELq0'}},
#            {'etag': 'imj_H77lz1qJ-cDY2RIKhOS3PJ4',
#             'id': 'UgzA70mQ5A3U-MJ0LfV4AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': '0M81dWk2lUsV_2Y0ayoSNLoctFk',
#                                             'id': 'UgzA70mQ5A3U-MJ0LfV4AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UCohK1hx5gD3OG_YtnUWHz6A'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/@strop100',
#                                                         'authorDisplayName': '@strop100',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZQlqGbyj2dvU7YcdLQQgQATpGy41UpR-KTIGmnX=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                         'likeCount': 2,
#                                                         'publishedAt': '2024-01-19T10:10:31Z',
#                                                         'textDisplay': 'Фильм '
#                                                                        '- '
#                                                                        'говно...С '
#                                                                        'первым '
#                                                                        'фильмом '
#                                                                        'никакого '
#                                                                        'сравнения...',
#                                                         'textOriginal': 'Фильм '
#                                                                         '- '
#                                                                         'говно...С '
#                                                                         'первым '
#                                                                         'фильмом '
#                                                                         'никакого '
#                                                                         'сравнения...',
#                                                         'updatedAt': '2024-01-19T10:10:31Z',
#                                                         'videoId': 'd9MyW72ELq0',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': 'd9MyW72ELq0'}},
#            {'etag': 'J0HoS30RBr7DT8vbqKjtds5z5Dg',
#             'id': 'UgwSQyjdtZAfQre0b7F4AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': 'DV2nM3BHZOBhARyJ3SkKVlZxFRM',
#                                             'id': 'UgwSQyjdtZAfQre0b7F4AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UCMi9zxFCqLt9rmHZ9vIxIFg'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/@carlyannweller',
#                                                         'authorDisplayName': '@carlyannweller',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZQzz4oEZXcjzcSSzTad5lTLvBIF-mYJ_yYjQH-qyg=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                         'likeCount': 1,
#                                                         'publishedAt': '2024-01-19T09:48:37Z',
#                                                         'textDisplay': 'What '
#                                                                        'an '
#                                                                        'amazing '
#                                                                        'movie! '
#                                                                        'After '
#                                                                        'seeing '
#                                                                        'trailer '
#                                                                        'I’m '
#                                                                        'like '
#                                                                        'eh not '
#                                                                        'going '
#                                                                        'to be '
#                                                                        'as '
#                                                                        'good '
#                                                                        'as '
#                                                                        'first. '
#                                                                        'But '
#                                                                        'the '
#                                                                        'love '
#                                                                        'for '
#                                                                        'family '
#                                                                        'was '
#                                                                        'amazing!  '
#                                                                        'I '
#                                                                        'cried '
#                                                                        'alittle '
#                                                                        ':)',
#                                                         'textOriginal': 'What '
#                                                                         'an '
#                                                                         'amazing '
#                                                                         'movie! '
#                                                                         'After '
#                                                                         'seeing '
#                                                                         'trailer '
#                                                                         'I’m '
#                                                                         'like '
#                                                                         'eh '
#                                                                         'not '
#                                                                         'going '
#                                                                         'to be '
#                                                                         'as '
#                                                                         'good '
#                                                                         'as '
#                                                                         'first. '
#                                                                         'But '
#                                                                         'the '
#                                                                         'love '
#                                                                         'for '
#                                                                         'family '
#                                                                         'was '
#                                                                         'amazing!  '
#                                                                         'I '
#                                                                         'cried '
#                                                                         'alittle '
#                                                                         ':)',
#                                                         'updatedAt': '2024-01-19T09:48:37Z',
#                                                         'videoId': 'd9MyW72ELq0',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': 'd9MyW72ELq0'}},
#            {'etag': '4geoUqc5qxLXuyNW_qpyPm7QFjU',
#             'id': 'UgyOYqpnAHY2UmSkOBB4AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': 'mbZB-xCwIJZDjIjhCmCYYpEVhOA',
#                                             'id': 'UgyOYqpnAHY2UmSkOBB4AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UCDR14VaDyGnzeogOOPwRlEg'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/@hemalatalokeshkushawah9718',
#                                                         'authorDisplayName': '@hemalatalokeshkushawah9718',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/sQxWpOPAI65_RMReUCAZmKuw0Xdho-RXM1kVxUH7tPqBVs10jntg25I0CCybkeqB-N7ZtHBPF94=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                         'likeCount': 1,
#                                                         'publishedAt': '2024-01-18T16:21:48Z',
#                                                         'textDisplay': 'I m '
#                                                                        'live '
#                                                                        'in '
#                                                                        'watch '
#                                                                        'avataarv3....weak '
#                                                                        'English',
#                                                         'textOriginal': 'I m '
#                                                                         'live '
#                                                                         'in '
#                                                                         'watch '
#                                                                         'avataarv3....weak '
#                                                                         'English',
#                                                         'updatedAt': '2024-01-18T16:22:45Z',
#                                                         'videoId': 'd9MyW72ELq0',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': 'd9MyW72ELq0'}},
#            {'etag': 'Nb9yAs6xyJVljpKP3m3eor0AyMc',
#             'id': 'UgzRg3zMhifoV2rhkC94AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': 'aQKP0ey843ClrbQwfm4xm7Suamw',
#                                             'id': 'UgzRg3zMhifoV2rhkC94AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UC3iUCsX6UuygOzoahRjbENQ'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/@Abc123z1000',
#                                                         'authorDisplayName': '@Abc123z1000',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZRbtc_8zn8FtlkQPJVctZHUmhgrTz-h4EeUBCcj=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                         'likeCount': 1,
#                                                         'publishedAt': '2024-01-15T23:21:35Z',
#                                                         'textDisplay': 'Shiiiiiiiit, '
#                                                                        'one of '
#                                                                        'my '
#                                                                        'friends '
#                                                                        'saw '
#                                                                        'this '
#                                                                        'movie '
#                                                                        'and '
#                                                                        'said '
#                                                                        'it was '
#                                                                        '"meh" '
#                                                                        'and '
#                                                                        '"okay". '
#                                                                        'But '
#                                                                        'now, '
#                                                                        'looking '
#                                                                        'at the '
#                                                                        'trailer, '
#                                                                        'it '
#                                                                        'gave '
#                                                                        'me '
#                                                                        'GOOSEBUMPS. '
#                                                                        'I need '
#                                                                        'to '
#                                                                        'find '
#                                                                        'this '
#                                                                        'movie '
#                                                                        'so I '
#                                                                        'can '
#                                                                        'watch '
#                                                                        'it 🤔',
#                                                         'textOriginal': 'Shiiiiiiiit, '
#                                                                         'one '
#                                                                         'of my '
#                                                                         'friends '
#                                                                         'saw '
#                                                                         'this '
#                                                                         'movie '
#                                                                         'and '
#                                                                         'said '
#                                                                         'it '
#                                                                         'was '
#                                                                         '"meh" '
#                                                                         'and '
#                                                                         '"okay". '
#                                                                         'But '
#                                                                         'now, '
#                                                                         'looking '
#                                                                         'at '
#                                                                         'the '
#                                                                         'trailer, '
#                                                                         'it '
#                                                                         'gave '
#                                                                         'me '
#                                                                         'GOOSEBUMPS. '
#                                                                         'I '
#                                                                         'need '
#                                                                         'to '
#                                                                         'find '
#                                                                         'this '
#                                                                         'movie '
#                                                                         'so I '
#                                                                         'can '
#                                                                         'watch '
#                                                                         'it 🤔',
#                                                         'updatedAt': '2024-01-15T23:21:35Z',
#                                                         'videoId': 'd9MyW72ELq0',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': 'd9MyW72ELq0'}},
#            {'etag': 'yhzhfL6zeMfZcUmjfBpZhxKNFrg',
#             'id': 'UgwlgNyzl543_KsO9I14AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': 'c4Dvvhp3KrJzwUjB1zbIjOHMbU8',
#                                             'id': 'UgwlgNyzl543_KsO9I14AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UCsM6xQ-kmIrXXobaf69z3KQ'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/@sezden8479',
#                                                         'authorDisplayName': '@sezden8479',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/7l5zFx2v1vTTeuzsG1JTiWdLBeb4ShdSgTjwb_d4ZItD8pYs2vBm7e-8FbDUWBpyaFE2zN3V7Jc=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                         'likeCount': 2,
#                                                         'publishedAt': '2024-01-14T19:07:39Z',
#                                                         'textDisplay': 'Breathless '
#                                                                        'movie, '
#                                                                        'into '
#                                                                        'ALL '
#                                                                        'aspects! '
#                                                                        '10 + + '
#                                                                        'from '
#                                                                        'me, '
#                                                                        'either '
#                                                                        'the '
#                                                                        'preferred '
#                                                                        'long '
#                                                                        'movie '
#                                                                        'length, '
#                                                                        'being '
#                                                                        'very '
#                                                                        'rare '
#                                                                        'as '
#                                                                        'such! '
#                                                                        '👌👌👌👏👏👏👏💖💖💖',
#                                                         'textOriginal': 'Breathless '
#                                                                         'movie, '
#                                                                         'into '
#                                                                         'ALL '
#                                                                         'aspects! '
#                                                                         '10 + '
#                                                                         '+ '
#                                                                         'from '
#                                                                         'me, '
#                                                                         'either '
#                                                                         'the '
#                                                                         'preferred '
#                                                                         'long '
#                                                                         'movie '
#                                                                         'length, '
#                                                                         'being '
#                                                                         'very '
#                                                                         'rare '
#                                                                         'as '
#                                                                         'such! '
#                                                                         '👌👌👌👏👏👏👏💖💖💖',
#                                                         'updatedAt': '2024-01-14T19:07:39Z',
#                                                         'videoId': 'd9MyW72ELq0',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': 'd9MyW72ELq0'}},
#            {'etag': 'WD8dptRT_3nZ5Sn5ud6iA_zZe_w',
#             'id': 'Ugzyw8FoBJDVykyHhxJ4AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': 'VCsftkn4ORRxy9p21jtQbgMn2QY',
#                                             'id': 'Ugzyw8FoBJDVykyHhxJ4AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UCZx9pRw3CuwGaJmk8w9nM2g'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/@soryelhiyabi7771',
#                                                         'authorDisplayName': '@soryelhiyabi7771',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/Ql-CWRurDVi1R1h9ZKDPxq8uDGxsRWo27tweQ0lZmbDMV3PTG20WywsusPxNuXzf6Zu5qfFilQ=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                         'likeCount': 3,
#                                                         'publishedAt': '2024-01-10T08:59:43Z',
#                                                         'textDisplay': 'Is it '
#                                                                        'me or '
#                                                                        'is it '
#                                                                        'that '
#                                                                        'avatar '
#                                                                        '1 is '
#                                                                        'better '
#                                                                        'than '
#                                                                        'this '
#                                                                        'second '
#                                                                        'part?',
#                                                         'textOriginal': 'Is it '
#                                                                         'me or '
#                                                                         'is it '
#                                                                         'that '
#                                                                         'avatar '
#                                                                         '1 is '
#                                                                         'better '
#                                                                         'than '
#                                                                         'this '
#                                                                         'second '
#                                                                         'part?',
#                                                         'updatedAt': '2024-01-10T08:59:43Z',
#                                                         'videoId': 'd9MyW72ELq0',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': 'd9MyW72ELq0'}},
#            {'etag': 'Ms3LdsIH6pB7pkmy2cyvi6rK9l0',
#             'id': 'UgyNqHb2mwbjqwVhQBR4AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': 'fDKZ71cUNC7TkhKgv4YS5YBBCiA',
#                                             'id': 'UgyNqHb2mwbjqwVhQBR4AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UC0l1AAiTEHX0ejHAUWOiKGA'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/@nathanchong7731',
#                                                         'authorDisplayName': '@nathanchong7731',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZRPBKKr8UP9Ij5qU6Y6oVEMk255vzk-9rGcdfsSgy4=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                         'likeCount': 0,
#                                                         'publishedAt': '2024-01-09T18:49:07Z',
#                                                         'textDisplay': '😊❤😊❤😊❤😊❤😊❤\n'
#                                                                        '\n'
#                                                                        'Still '
#                                                                        'loving '
#                                                                        'this '
#                                                                        'trailer '
#                                                                        'till '
#                                                                        'date',
#                                                         'textOriginal': '😊❤😊❤😊❤😊❤😊❤\n'
#                                                                         '\n'
#                                                                         'Still '
#                                                                         'loving '
#                                                                         'this '
#                                                                         'trailer '
#                                                                         'till '
#                                                                         'date',
#                                                         'updatedAt': '2024-01-09T18:49:07Z',
#                                                         'videoId': 'd9MyW72ELq0',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': 'd9MyW72ELq0'}},
#            {'etag': '7HPgebzW70SkIbRN0jipmY8ckIU',
#             'id': 'Ugza1y8fWhk6yvJtQwR4AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': 'XoLskjuURR5rKc_ACmKFFvSq0zo',
#                                             'id': 'Ugza1y8fWhk6yvJtQwR4AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UCD3Y8NgOfBlkPnTijLbDC0A'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/@mdgouse6729',
# ...
#                                                                         'complete '
#                                                                         'lack '
#                                                                         'of '
#                                                                         'chill '
#                                                                         'or '
#                                                                         'understanding '
#                                                                         'where '
#                                                                         "they're "
#                                                                         'blundering '
#                                                                         'through '
#                                                                         'sacred '
#                                                                         'sites',
#                                                         'updatedAt': '2024-02-02T18:29:44Z',
#                                                         'videoId': 'RGx8rYbRVR4',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': 'RGx8rYbRVR4'}},
#            {'etag': 'yLOwiEDskOXhUUJ6wkJvwix1WgY',
#             'id': 'UgwYUoRKu-xyWfv1Wvx4AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCI9DUIgtRGHNH_HmSTcfUbA',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': 'hZJcojvfgNvPE-39wTmX53eYUZ8',
#                                             'id': 'UgwYUoRKu-xyWfv1Wvx4AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UCN3N9TdkBsd4EpmVYxjJ0rQ'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/@SuperDuperSentinel',
#                                                         'authorDisplayName': '@SuperDuperSentinel',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZRoEtg6S6jKiro1pvdEYK1wakS4YPmWWnoFyg=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCI9DUIgtRGHNH_HmSTcfUbA',
#                                                         'likeCount': 0,
#                                                         'publishedAt': '2024-02-02T11:02:19Z',
#                                                         'textDisplay': 'Well '
#                                                                        'these '
#                                                                        'criticisms '
#                                                                        'might '
#                                                                        'be '
#                                                                        'pre-mature '
#                                                                        'because '
#                                                                        'it '
#                                                                        'seems '
#                                                                        'like '
#                                                                        'this '
#                                                                        'is '
#                                                                        'where '
#                                                                        'the '
#                                                                        'story '
#                                                                        'is '
#                                                                        'going. '
#                                                                        'From '
#                                                                        'my '
#                                                                        'understanding, '
#                                                                        'there '
#                                                                        'are 3 '
#                                                                        'more '
#                                                                        'sequels '
#                                                                        'planned '
#                                                                        'and '
#                                                                        'Cameron '
#                                                                        'said '
#                                                                        'he '
#                                                                        'will '
#                                                                        'explore '
#                                                                        'the '
#                                                                        'dark '
#                                                                        'side '
#                                                                        'of the '
#                                                                        'Navi '
#                                                                        'in the '
#                                                                        '3rd. \n'
#                                                                        '\n'
#                                                                        'Additionally, '
#                                                                        'we see '
#                                                                        'in the '
#                                                                        'second '
#                                                                        'one '
#                                                                        'Neytiri '
#                                                                        'has a '
#                                                                        'strong '
#                                                                        'hatred '
#                                                                        'for '
#                                                                        'humans: '
#                                                                        'she '
#                                                                        'becomes '
#                                                                        'a '
#                                                                        'bigot, '
#                                                                        'even '
#                                                                        'willing '
#                                                                        'to '
#                                                                        'kill '
#                                                                        'an '
#                                                                        'innocent '
#                                                                        'kid '
#                                                                        'because '
#                                                                        'he is '
#                                                                        'human. '
#                                                                        'Unsurprisingly, '
#                                                                        'she is '
#                                                                        'the '
#                                                                        'most '
#                                                                        '(the '
#                                                                        'only) '
#                                                                        'interesting '
#                                                                        'character '
#                                                                        'in the '
#                                                                        'franchise '
#                                                                        'by far',
#                                                         'textOriginal': 'Well '
#                                                                         'these '
#                                                                         'criticisms '
#                                                                         'might '
#                                                                         'be '
#                                                                         'pre-mature '
#                                                                         'because '
#                                                                         'it '
#                                                                         'seems '
#                                                                         'like '
#                                                                         'this '
#                                                                         'is '
#                                                                         'where '
#                                                                         'the '
#                                                                         'story '
#                                                                         'is '
#                                                                         'going. '
#                                                                         'From '
#                                                                         'my '
#                                                                         'understanding, '
#                                                                         'there '
#                                                                         'are 3 '
#                                                                         'more '
#                                                                         'sequels '
#                                                                         'planned '
#                                                                         'and '
#                                                                         'Cameron '
#                                                                         'said '
#                                                                         'he '
#                                                                         'will '
#                                                                         'explore '
#                                                                         'the '
#                                                                         'dark '
#                                                                         'side '
#                                                                         'of '
#                                                                         'the '
#                                                                         'Navi '
#                                                                         'in '
#                                                                         'the '
#                                                                         '3rd. \n'
#                                                                         '\n'
#                                                                         'Additionally, '
#                                                                         'we '
#                                                                         'see '
#                                                                         'in '
#                                                                         'the '
#                                                                         'second '
#                                                                         'one '
#                                                                         'Neytiri '
#                                                                         'has a '
#                                                                         'strong '
#                                                                         'hatred '
#                                                                         'for '
#                                                                         'humans: '
#                                                                         'she '
#                                                                         'becomes '
#                                                                         'a '
#                                                                         'bigot, '
#                                                                         'even '
#                                                                         'willing '
#                                                                         'to '
#                                                                         'kill '
#                                                                         'an '
#                                                                         'innocent '
#                                                                         'kid '
#                                                                         'because '
#                                                                         'he is '
#                                                                         'human. '
#                                                                         'Unsurprisingly, '
#                                                                         'she '
#                                                                         'is '
#                                                                         'the '
#                                                                         'most '
#                                                                         '(the '
#                                                                         'only) '
#                                                                         'interesting '
#                                                                         'character '
#                                                                         'in '
#                                                                         'the '
#                                                                         'franchise '
#                                                                         'by '
#                                                                         'far',
#                                                         'updatedAt': '2024-02-02T11:02:19Z',
#                                                         'videoId': 'RGx8rYbRVR4',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': 'RGx8rYbRVR4'}}],
#  'kind': 'youtube#commentThreadListResponse',
#  'nextPageToken': 'Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNKMGdHQUVTQlFpSElCZ0FFZ1VJaVNBWUFCSUZDS2dnR0FBU0JRaUlJQmdBR0FBaURnb01DTHFYODYwR0VJalVuTDhD',
#  'pageInfo': {'resultsPerPage': 20, 'totalResults': 20}}

# %% [markdown]
# > 3.c Write a program to export the output of question 3.b in JSON file format and submit the file as part of the assignment (3 marks)

# %%
import json

with open('3b_video_comments.json', 'w') as jsonf:
  json.dump(comments_on_videos, jsonf, ensure_ascii=False, indent=2)

# %% [markdown]
# >3.d Write a function to get  the likes vs views ratio of the top 10 videos obtained in 3.a with the highest comments (3 marks)

# %%
def get_likes_views_ratio(video_data_row):
  likes = video_data_row['total_likes']
  views = video_data_row['total_views']
  if views == 0:
    return float('inf')
  return likes/views

def get_all_likes_views_ratio(video_data):
  likes_views = []
  for index, row in video_data.iterrows():
    likes_views.append(get_likes_views_ratio(row))
  return likes_views

likes_views = get_all_likes_views_ratio(top_10_comments)
print(likes_views)
# Out:
# [0.01780110408801011, 0.02279115533301114, 0.024409558301083923, 0.030070497679658897, 0.04086704313811995, 0.002089046082081093, 0.04245095447791101, 0.006327934736220237, 0.04682316225421322, 0.05628171472149708]
