# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### Methane is responsible for around 30% of the rise in global temperatures since the Industrial Revolution, and rapid and sustained reductions in methane emissions are key to limiting near-term global warming and improving air quality. The energy sector – including oil, natural gas, coal and bioenergy – accounts for nearly 40% of methane emissions from human activity.
#
#
# The following dataset has information about methane gas emissions globally. Details about the columns are as follows.
#
# - region - region of the world
# - country - Country of Emission.
# - emissions - Methane Emissions in kt.
# - type - Sector from which emissions occur.
# - Segment- Sub-sector from which emissions occur.
# - reason - The reason for the emission.
# - baseYear - Base year for the tracking of emissions.
# - notes - The source of data

# %% [markdown]
# ### <font color='red'>* Try answering the questions in Markdown from the dataset. *</font>

# %%
df=pd.read_csv("Methane_final.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  region  country   emissions         type  \
# 0           0  Africa  Algeria  257.611206  Agriculture
# 1           1  Africa  Algeria    0.052000       Energy
# 2           2  Africa  Algeria  130.798996       Energy
# 3           3  Africa  Algeria   69.741898       Energy
# 4           4  Africa  Algeria  213.987000       Energy
#
#                             segment    reason   baseYear  \
# 0                             Total       All  2019-2021
# 1                         Bioenergy       All       2022
# 2  Gas pipelines and LNG facilities  Fugitive       2022
# 3  Gas pipelines and LNG facilities    Vented       2022
# 4                       Onshore gas  Fugitive       2022
#
#                                                notes
# 0  Average based on United Nations Framework Conv...
# 1  Estimates from end-uses are for 2020 or 2021 (...
# 2                                      Not available
# 3                                      Not available
# 4                                      Not available

# %% [markdown]
# #### 1) How many numerical and categorical columns are there in the dataset?

# %%
# We clearly see that there are 2 numerical and 7 categorical columns in the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1548 entries, 0 to 1547
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1548 non-null   int64
#  1   region      1548 non-null   object
#  2   country     1548 non-null   object
#  3   emissions   1548 non-null   float64
#  4   type        1548 non-null   object
#  5   segment     1548 non-null   object
#  6   reason      1548 non-null   object
#  7   baseYear    1548 non-null   object
#  8   notes       1548 non-null   object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 109.0+ KB

# %% [markdown]
# #### 2) Display the emission levels as present in the last 100 rows of data?

# %%
df.index,df.shape
# Out:
# (RangeIndex(start=0, stop=1548, step=1), (1548, 9))

# %%
# Out:
#           emissions
# 1448     762.098083
# 1449       0.604000
# 1450     103.285004
# 1451      60.720402
# 1452      32.376099
# ...             ...
# 1543    3102.500000
# 1544   30296.500000
# 1545  133350.984375
# 1546    9737.874023
# 1547   70758.710938
#
# [100 rows x 1 columns]

# %% [markdown]
# #### 3) How many unique sectors in the data are responsible for emissions and which sector is captured most in the data?

# %%
# 4 unique sectors are responsible for emissions
# Out:
# array(['Agriculture', 'Energy', 'Other', 'Waste'], dtype=object)

# %%
# Energy sector is captured most in the data
# Out:
# 0    Energy
# Name: type, dtype: object

# %% [markdown]
# #### 4) What is the minimum and maximum emission level rounded upto 3 decimal places for a country like 'Algeria'?

# %%
# Out:
# 0.004

# %%
# Out:
# 2669.195

# %% [markdown]
# #### 5) Remove any leading and trailing spaces from the 'notes' column for all the rows and replace ' "Not avaialble" with "NA" '

# %%
# Out:
# 0       Average based on United Nations Framework Conv...
# 1       Estimates from end-uses are for 2020 or 2021 (...
# 2                                                      NA
# 3                                                      NA
# 4                                                      NA
#                               ...
# 1543                                                   NA
# 1544                                                   NA
# 1545    Estimates from end-uses are for 2020 or 2021 (...
# 1546    Average based on United Nations Framework Conv...
# 1547    Average based on United Nations Framework Conv...
# Name: notes, Length: 1548, dtype: object

# %% [markdown]
# #### 6) Display all those rows where the emission levels are more than the mean emission level?

# %%
df.emissions.mean()
# Out:
# 643.2559723044416

# %%
# Out:
#       Unnamed: 0  region   country      emissions         type  \
# 8              8  Africa   Algeria    1154.119995       Energy
# 12            12  Africa   Algeria    2669.194580       Energy
# 48            48  Africa  Botswana     843.401672        Waste
# 67            67  Africa      Chad    1223.932983  Agriculture
# 118          118  Africa     Egypt     684.532227  Agriculture
# ...          ...     ...       ...            ...          ...
# 1543        1543   World     World    3102.500000       Energy
# 1544        1544   World     World   30296.500000       Energy
# 1545        1545   World     World  133350.984375       Energy
# 1546        1546   World     World    9737.874023        Other
# 1547        1547   World     World   70758.710938        Waste
#
#                                              segment  reason   baseYear  \
# 8                                        Onshore oil  Vented       2022
# 12                                             Total     All       2022
# 48                                             Total     All  2019-2021
# 67                                             Total     All  2019-2021
# 118                                            Total     All  2019-2021
# ...                                              ...     ...        ...
# 1543  Satellite-detected large oil and gas emissions     All       2022
# 1544                                      Steam coal     All       2022
# 1545                                           Total     All       2022
# 1546                                           Total     All  2019-2021
# 1547                                           Total     All  2019-2021
#
#                                                   notes
# 8                                         Not available
# 12    Estimates from end-uses are for 2020 or 2021 (...
# 48    Average based on United Nations Framework Conv...
# 67    Average based on United Nations Framework Conv...
# 118   Average based on United Nations Framework Conv...
# ...                                                 ...
# 1543                                      Not available
# 1544                                      Not available
# 1545  Estimates from end-uses are for 2020 or 2021 (...
# 1546  Average based on United Nations Framework Conv...
# 1547  Average based on United Nations Framework Conv...
#
# [177 rows x 9 columns]

# %% [markdown]
# #### 7) Are there any countries which have emissions from the 'Bioenergy' segment in the year '2022'?

# %%
df.baseYear.value_counts()
# Out:
# 2022         1233
# 2019-2021     315
# Name: baseYear, dtype: int64

# %%
# Yes there are countries which have emissions from the 'Bioenergy' segment in the year '2022'
# Out:
# array(['Algeria', 'Angola', 'Benin', 'Botswana', 'Cameroon', 'Congo',
#        "Cote d'Ivoire", 'Democratic Republic of Congo', 'Egypt',
#        'Equatorial Guinea', 'Eritrea', 'Ethiopia', 'Gabon', 'Ghana',
#        'Kenya', 'Libya', 'Morocco', 'Mozambique', 'Namibia', 'Niger',
#        'Nigeria', 'Senegal', 'Somalia', 'South Africa', 'South Sudan',
#        'Sudan', 'Tanzania', 'Togo', 'Tunisia', 'Australia', 'Bangladesh',
#        'China', 'India', 'Indonesia', 'Japan', 'Korea', 'Malaysia',
#        'Mongolia', 'New Zealand', 'Other countries in Southeast Asia',
#        'Pakistan', 'Philippines', 'Thailand', 'Vietnam', 'Argentina',
#        'Bolivia', 'Brazil', 'Colombia', 'Cuba', 'Ecuador', 'Guyana',
#        'Paraguay', 'Peru', 'Trinidad and Tobago', 'Uruguay', 'Venezuela',
#        'Denmark', 'Estonia', 'European Union', 'France', 'Germany',
#        'Israel', 'Italy', 'Netherlands', 'Norway',
#        'Other countries in Europe', 'Other EU17 countries',
#        'Other EU7 countries', 'Poland', 'Romania', 'Slovenia', 'Sweden',
#        'Ukraine', 'United Kingdom', 'Iran', 'Iraq', 'Jordan', 'Lebanon',
#        'Qatar', 'Saudi Arabia', 'Syria', 'United Arab Emirates', 'Yemen',
#        'Canada', 'Mexico', 'United States', 'Other', 'Azerbaijan',
#        'Kazakhstan', 'Russia', 'Turkmenistan', 'Uzbekistan', 'World'],
#       dtype=object)

# %% [markdown]
# #### 8) Which region has the most emissons from the 'Onshore gas' more than the median emission levels ?

# %%
df['emissions'].median()
# Out:
# 24.064668655395508

# %%
# Out:
#       Unnamed: 0                     region               country  \
# 4              4                     Africa               Algeria
# 5              5                     Africa               Algeria
# 128          128                     Africa                 Egypt
# 231          231                     Africa                 Libya
# 297          297                     Africa               Nigeria
# 298          298                     Africa               Nigeria
# 416          416               Asia Pacific             Australia
# 417          417               Asia Pacific             Australia
# 432          432               Asia Pacific            Bangladesh
# 433          433               Asia Pacific            Bangladesh
# 470          470               Asia Pacific                 China
# 471          471               Asia Pacific                 China
# 492          492               Asia Pacific                 India
# 513          513               Asia Pacific             Indonesia
# 514          514               Asia Pacific             Indonesia
# 622          622               Asia Pacific              Pakistan
# 623          623               Asia Pacific              Pakistan
# 685          685  Central and South America             Argentina
# 686          686  Central and South America             Argentina
# 700          700  Central and South America               Bolivia
# 701          701  Central and South America               Bolivia
# 738          738  Central and South America              Colombia
# 804          804  Central and South America                  Peru
# 848          848  Central and South America             Venezuela
# 849          849  Central and South America             Venezuela
# 894          894                     Europe        European Union
# 895          895                     Europe        European Union
# 1091        1091                     Europe               Romania
# 1092        1092                     Europe               Romania
# 1129        1129                     Europe               Ukraine
# 1130        1130                     Europe               Ukraine
# 1164        1164                Middle East               Bahrain
# 1165        1165                Middle East               Bahrain
# 1183        1183                Middle East                  Iran
# 1184        1184                Middle East                  Iran
# 1200        1200                Middle East                  Iraq
# 1230        1230                Middle East                Kuwait
# 1254        1254                Middle East                  Oman
# 1255        1255                Middle East                  Oman
# 1290        1290                Middle East          Saudi Arabia
# 1291        1291                Middle East          Saudi Arabia
# 1305        1305                Middle East                 Syria
# 1323        1323                Middle East  United Arab Emirates
# 1324        1324                Middle East  United Arab Emirates
# 1355        1355              North America                Canada
# 1356        1356              North America                Canada
# 1376        1376              North America                Mexico
# 1377        1377              North America                Mexico
# 1397        1397              North America         United States
# 1398        1398              North America         United States
# 1458        1458           Russia & Caspian            Kazakhstan
# 1459        1459           Russia & Caspian            Kazakhstan
# 1480        1480           Russia & Caspian                Russia
# 1481        1481           Russia & Caspian                Russia
# 1501        1501           Russia & Caspian          Turkmenistan
# 1502        1502           Russia & Caspian          Turkmenistan
# 1515        1515           Russia & Caspian            Uzbekistan
# 1516        1516           Russia & Caspian            Uzbekistan
# 1536        1536                      World                 World
# 1537        1537                      World                 World
#
#          emissions    type      segment    reason baseYear          notes
# 4       213.987000  Energy  Onshore gas  Fugitive     2022  Not available
# 5       464.308014  Energy  Onshore gas    Vented     2022  Not available
# 128      40.961601  Energy  Onshore gas    Vented     2022  Not available
# 231      48.940300  Energy  Onshore gas    Vented     2022  Not available
# 297      63.722599  Energy  Onshore gas  Fugitive     2022  Not available
# 298     138.264999  Energy  Onshore gas    Vented     2022  Not available
# 416      45.123402  Energy  Onshore gas  Fugitive     2022  Not available
# 417      97.908302  Energy  Onshore gas    Vented     2022  Not available
# 432      39.714500  Energy  Onshore gas  Fugitive     2022  Not available
# 433      86.172203  Energy  Onshore gas    Vented     2022  Not available
# 470     254.276001  Energy  Onshore gas  Fugitive     2022  Not available
# 471     551.726013  Energy  Onshore gas    Vented     2022  Not available
# 492      33.435799  Energy  Onshore gas    Vented     2022  Not available
# 513      45.647202  Energy  Onshore gas  Fugitive     2022  Not available
# 514      99.044899  Energy  Onshore gas    Vented     2022  Not available
# 622      68.321999  Energy  Onshore gas  Fugitive     2022  Not available
# 623     148.244995  Energy  Onshore gas    Vented     2022  Not available
# 685     129.520004  Energy  Onshore gas  Fugitive     2022  Not available
# 686     281.032013  Energy  Onshore gas    Vented     2022  Not available
# 700      26.052799  Energy  Onshore gas  Fugitive     2022  Not available
# 701      56.529099  Energy  Onshore gas    Vented     2022  Not available
# 738      32.948700  Energy  Onshore gas    Vented     2022  Not available
# 804      30.165501  Energy  Onshore gas    Vented     2022  Not available
# 848      43.007301  Energy  Onshore gas  Fugitive     2022  Not available
# 849      93.316902  Energy  Onshore gas    Vented     2022  Not available
# 894      44.330601  Energy  Onshore gas  Fugitive     2022  Not available
# 895      96.188103  Energy  Onshore gas    Vented     2022  Not available
# 1091     28.021799  Energy  Onshore gas  Fugitive     2022  Not available
# 1092     60.801399  Energy  Onshore gas    Vented     2022  Not available
# 1129     24.091101  Energy  Onshore gas  Fugitive     2022  Not available
# 1130     52.272701  Energy  Onshore gas    Vented     2022  Not available
# 1164     25.437000  Energy  Onshore gas  Fugitive     2022  Not available
# 1165     55.193100  Energy  Onshore gas    Vented     2022  Not available
# 1183    108.269997  Energy  Onshore gas  Fugitive     2022  Not available
# 1184    234.923004  Energy  Onshore gas    Vented     2022  Not available
# 1200     27.543900  Energy  Onshore gas    Vented     2022  Not available
# 1230     51.958801  Energy  Onshore gas    Vented     2022  Not available
# 1254     79.915802  Energy  Onshore gas  Fugitive     2022  Not available
# 1255    173.401001  Energy  Onshore gas    Vented     2022  Not available
# 1290     54.821800  Energy  Onshore gas  Fugitive     2022  Not available
# 1291    118.952003  Energy  Onshore gas    Vented     2022  Not available
# 1305     24.812201  Energy  Onshore gas    Vented     2022  Not available
# 1323     43.503799  Energy  Onshore gas  Fugitive     2022  Not available
# 1324     94.394096  Energy  Onshore gas    Vented     2022  Not available
# 1355    323.264008  Energy  Onshore gas  Fugitive     2022  Not available
# 1356    701.416992  Energy  Onshore gas    Vented     2022  Not available
# 1376     27.290300  Energy  Onshore gas  Fugitive     2022  Not available
# 1377     59.214199  Energy  Onshore gas    Vented     2022  Not available
# 1397   1756.949951  Energy  Onshore gas  Fugitive     2022  Not available
# 1398   3812.209961  Energy  Onshore gas    Vented     2022  Not available
# 1458     79.211197  Energy  Onshore gas  Fugitive     2022  Not available
# 1459    171.871994  Energy  Onshore gas    Vented     2022  Not available
# 1480   1256.520020  Energy  Onshore gas  Fugitive     2022  Not available
# 1481   2726.389893  Energy  Onshore gas    Vented     2022  Not available
# 1501    600.879028  Energy  Onshore gas  Fugitive     2022  Not available
# 1502   1303.780029  Energy  Onshore gas    Vented     2022  Not available
# 1515    127.389000  Energy  Onshore gas  Fugitive     2022  Not available
# 1516    276.407990  Energy  Onshore gas    Vented     2022  Not available
# 1536   5665.069824  Energy  Onshore gas  Fugitive     2022  Not available
# 1537  12292.000000  Energy  Onshore gas    Vented     2022  Not available

# %%
# Middle East region has the most emissons from the 'Onshore gas' more than the median emission levels
# Out:
# 'Middle East'
